# %% [markdown]
# ### Import Necessary Libraries

# %%
# data handling
import pandas as pd

# pre-processing pipeline
import nltk

# Chunker
from flair.data import Sentence
from flair.models import SequenceTagger

# topic modelling
from bertopic import BERTopic

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv('../data/Defined_AI/DAI-healthcare-retail.tsv', sep='\t')

# %%
data
# Out:
#       TranscriptionId  Channel    StartTime      EndTime  \
# 0              596305        1  0:00:00.000  0:00:08.739
# 1              596306        2  0:00:09.600  0:00:15.823
# 2              596307        1  0:00:16.890  0:00:23.146
# 3              596308        2  0:00:24.176  0:00:29.207
# 4              596309        1  0:00:30.734  0:00:45.385
# ...               ...      ...          ...          ...
# 6404           596126        2  0:04:02.056  0:04:06.663
# 6405           596127        1  0:04:07.314  0:04:14.296
# 6406           596128        2  0:04:15.692  0:04:21.184
# 6407           596129        1  0:04:21.901  0:04:25.484
# 6408           596130        2  0:04:25.272  0:04:29.140
#
#                                           Transcription SegmentDuration  \
# 0     [n_s/] Hello there My name is "Anne" and thank...     0:00:08.739
# 1     Hi I was wondering to see if you could give me...     0:00:06.223
# 2     Oh absolutely I'd be happy to help [filler/] W...     0:00:06.256
# 3     I'm having cold and tingling in my [filler/] u...     0:00:05.031
# 4     oh dear I'm so sorry to hear that so you're sa...     0:00:14.651
# ...                                                 ...             ...
# 6404  [filler/] that's [n_s/] that's great so [n_s/]...     0:00:04.607
# 6405  [filler/] once a verified [filler/] you will g...     0:00:06.982
# 6406  okay well thank you so much [filler/] this pha...     0:00:05.492
# 6407  You're very welcome and thank you for calling ...     0:00:03.583
# 6408                                       okay bye bye     0:00:03.868
#
#                                RecordingId             Domain  SampleRate  \
# 0     1ff026c2-9fd0-4a7e-a4cd-8ea4268f3d23  healthcare-retail        8000
# 1     1ff026c2-9fd0-4a7e-a4cd-8ea4268f3d23  healthcare-retail        8000
# 2     1ff026c2-9fd0-4a7e-a4cd-8ea4268f3d23  healthcare-retail        8000
# 3     1ff026c2-9fd0-4a7e-a4cd-8ea4268f3d23  healthcare-retail        8000
# 4     1ff026c2-9fd0-4a7e-a4cd-8ea4268f3d23  healthcare-retail        8000
# ...                                    ...                ...         ...
# 6404  feddaf24-2b8d-4474-a089-5ce192e74f18  healthcare-retail        8000
# 6405  feddaf24-2b8d-4474-a089-5ce192e74f18  healthcare-retail        8000
# 6406  feddaf24-2b8d-4474-a089-5ce192e74f18  healthcare-retail        8000
# 6407  feddaf24-2b8d-4474-a089-5ce192e74f18  healthcare-retail        8000
# 6408  feddaf24-2b8d-4474-a089-5ce192e74f18  healthcare-retail        8000
#
#       BitDepth  ...  LeftChannelSpeakerAge LeftChannelSpeakerLivingCountry  \
# 0           16  ...                     45                   United States
# 1           16  ...                     45                   United States
# 2           16  ...                     45                   United States
# 3           16  ...                     45                   United States
# 4           16  ...                     45                   United States
# ...        ...  ...                    ...                             ...
# 6404        16  ...                     38                   United States
# 6405        16  ...                     38                   United States
# 6406        16  ...                     38                   United States
# 6407        16  ...                     38                   United States
# 6408        16  ...                     38                   United States
#
#      LeftChannelSpeakerAccent LeftChannelNative  \
# 0                  California              True
# 1                  California              True
# 2                  California              True
# 3                  California              True
# 4                  California              True
# ...                       ...               ...
# 6404                    Texas              True
# 6405                    Texas              True
# 6406                    Texas              True
# 6407                    Texas              True
# 6408                    Texas              True
#
#                      RightChannelSpeakerId RightChannelSpeakerGender  \
# 0     35170AE5-660E-43B2-84C9-046EA9E88E74                    Female
# 1     35170AE5-660E-43B2-84C9-046EA9E88E74                    Female
# 2     35170AE5-660E-43B2-84C9-046EA9E88E74                    Female
# 3     35170AE5-660E-43B2-84C9-046EA9E88E74                    Female
# 4     35170AE5-660E-43B2-84C9-046EA9E88E74                    Female
# ...                                    ...                       ...
# 6404  4FD155E2-679D-45D2-98C5-1A713AD828F4                    Female
# 6405  4FD155E2-679D-45D2-98C5-1A713AD828F4                    Female
# 6406  4FD155E2-679D-45D2-98C5-1A713AD828F4                    Female
# 6407  4FD155E2-679D-45D2-98C5-1A713AD828F4                    Female
# 6408  4FD155E2-679D-45D2-98C5-1A713AD828F4                    Female
#
#      RightChannelSpeakerAge  RightChannelSpeakerLivingCountry  \
# 0                        39                     United States
# 1                        39                     United States
# 2                        39                     United States
# 3                        39                     United States
# 4                        39                     United States
# ...                     ...                               ...
# 6404                     68                     United States
# 6405                     68                     United States
# 6406                     68                     United States
# 6407                     68                     United States
# 6408                     68                     United States
#
#      RightChannelSpeakerAccent RightChannelNative
# 0                      Arizona               True
# 1                      Arizona               True
# 2                      Arizona               True
# 3                      Arizona               True
# 4                      Arizona               True
# ...                        ...                ...
# 6404              Pennsylvania               True
# 6405              Pennsylvania               True
# 6406              Pennsylvania               True
# 6407              Pennsylvania               True
# 6408              Pennsylvania               True
#
# [6409 rows x 27 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Before, attempting to clean the data we must take a look at the data.

# %%
data.Transcription.to_list()[:100]
# Out:
# ['[n_s/] Hello there My name is "Anne" and thank you so much for calling us here at "Bartell Drugs" How may I help you today',
#  "Hi I was wondering to see if you could give me help finding an over the counter medication for some symptoms that I'm having",
#  "Oh absolutely I'd be happy to help [filler/] What particular symptoms are you experiencing",
#  "I'm having cold and tingling in my [filler/] upper leg area",
#  "oh dear I'm so sorry to hear that so you're saying you're having cold and tingling sensation and your upper leg area [n_s/] okay so [filler/] have you discussed this issue yet with your doctor",
#  "No I haven't yet kind of hard to get a hold of them",
#  "Oh yeah I understand Yes assume and how often you're having the symptoms in your leg",
#  "[filler/] I'd say like every other day usually in the morning [n_s/]",
#  '[n_s/] oh Okay I understand [filler/] may I also ask do you have a history of common diseases such as a heart disease diabetes or cancer',
#  '[filler/] Yeah I actually Do I have high cholesterol and my grandmother has diabetes [n_s/]',
#  '[n_s/] Oh okay thank you so much for sharing that information so [filler/] putting that into my system here [filler/] what I can recommend is a couple of options so there\'s two medications that pop up that could help you with your symptoms One is called "Nexium" and the other one is called "NyQuil" ',
#  'Okay although you never taken either of those medications Is there any way you could like give me more information about them',
#  'Ohh yes absolutely So [filler/] the way that "Nexium" works is that [filler/] it\'s taken daily for extended treatment So if you\'re having this you\'re having this [filler/] you know the problem with her legs on a daily basis then I would recommend you take the [uni/] "Nexium" every day for that and it will help you with that And the way the night will work It\'s more for like as your symptoms flare up So it\'s like it as needed basis type of medication',
#  'okay I understand and [filler/] would you say these are chosen like say for me to take',
#  '[filler/] yes I would say they\'re mostly safe but I mean unfortunately you know every drug does have a few side effects [n_s/] that come with it so [filler/] for "Nexium" some people have experienced headaches and then for the "NyQuil" sometimes people have like indigestion so those are some of the side effects that might occur with those medication but I would recommend that you consult with your doctor if your symptoms don\'t [filler/] diminish after you start taking one of these medications',
#  '[n_s/] Okay great and Is there any [filler/] like non-drug remedies for the symptom',
#  "[filler/] yes I also wanted to mention to you that you shouldn't take [filler/] the daily medication longer for three weeks okay [filler/] but yes in terms of home remedy [filler/] [filler/] some ideas that [filler/] that pop in my head are things like you could try a heating pad or maybe like a massage or maybe some people have [filler/] had lessened their symptoms by eating less red meat",
#  '[n_s/] okay',
#  '[n_s/] Okay great and [filler/]',
#  '[filler/] Sorry I was wondering [filler/] do you sell any of those things [filler/] like heating pad massage pads or anything like that',
#  '[filler/] [n_s/] yes actually we do sell several of them we have different types we have like [filler/] the heating pads that you plug in [filler/] that our electric and then we also have ones that are microwavable and then you put it on your on your body to heat you up [filler/] so yeah I would suggest you come into the pharmacy to check them out',
#  "[n_s/] alright great I'll definitely do that [filler/] what time is the store open",
#  "[n_s/] yes sir we're open everyday from six A. M. to eleven P. M.",
#  'alright great thank you so much and [filler/] are those products on the stores website for purchase also',
#  '[n_s/] Oh yes they are available on our website so our website address is W.W.W. dot "Bartel Drugs" dot com',
#  '[n_s/] okay and [filler/] does the website also have the coupons that you offer in the store',
#  "Oh yeah [filler/] on her home page We do have a coupon tab on the upper left hand corner and that's where you can find our weekly coupons and discounts",
#  'Okay great Thank you so much your help I really appreciate it',
#  "Oh absolutely I'm glad I was able to help today and I hope you have a wonderful rest of your day Okay and goodbye",
#  'bye thank you [n_s/]',
#  '[n_s/] Hi how you doing today Thank you for calling "Bartell Drugs" My name is "Sherry" How can I help you',
#  'Hi Sherry [filler/] I would like to know about birth control options',
#  "sure I'd be happy to help you with that [filler/] I do need to ask first what is your age okay perfect just have to make sure that you're over the threshold of eighteen before we start discussing anything sensitive so",
#  "although I'm definitely over eighteen I voted",
#  "[uni/] perfect I'm talking to [filler/] card Carrying adults So do you have any specific questions [n_s/]",
#  "[filler/] [filler/] what's the most popular options I'm not popular but I really want to be so maybe my birth control can make me popular",
#  "understood so actually [filler/] it's really hard to say what the most popular one is because there are so many different reasons why somebody chooses the birth control that they choose It's really it's not one size fits all it's very unique and tailored to the individual [n_s/]",
#  'So do you think Condoms are the best option',
#  "[n_s/] Condoms are a great option they are convenient you can find them almost anywhere they're relatively inexpensive they are over the counter so you don't have to worry about going and getting a prescription for him [filler/] when they are used properly they're over ninety-nine percent effective at preventing [filler/] pregnancy and they also have the added benefit of they're able to provide the transmission of some S.T.D.",
#  '[filler/] "S.T.D\'s" are we in the nineties i thought they were was called "S.T.I\'s" okay so what are the downside',
#  "so one of the biggest ones is is if you're allergic to latex that is what most of the brands carry however there are some that are not [filler/] latex so there are options [filler/]",
#  "[filler/] I definitely have a latex allergy that's what I tell everyone",
#  "okay well there are normally text alternatives you just have to make sure you read the label before you purchase and well the pill does require a prescription from your doctor and right now it is only available for females so [filler/] they are actually working on a male birth control pill but they haven't released it yet",
#  'i think so i think the ability to have continuous birth control as a man would probably be really nice',
#  'okay so those advantages are what are the advantages',
#  "They are really easy to take they're super tiny Most people don't even need any water to take em they are extremely reliable and what's really nice about them And I think with a lot of people prefer is that it is continuous there There doesn't need to be an extra step actually in the moment to think about you just your birth control taken care of for you",
#  "OH That sounds really nice in your your sure it's only for females right now Alright",
#  "yes [filler/] the last I read they are testing in males but it's not ready to be released [n_s/]",
#  "so that's one disadvantage what are other disadvantages for the pill",
#  '[filler/] there are some side effects one of the main ones is weight gain [filler/] but there is actually a good side effect it can [filler/] help with acne problems [filler/] so',
#  '[filler/] I got you',
#  "[n_s/] Yeah but not quite for you You [n_s/] [filler/] no the one bad thing about the pill is that it doesn't heard that prevent S.T.D.s It's just a measure to prevent pregnancy",
#  '[filler/] so so doesn\'t ".S.T.D\'s" i still confused about that term but [filler/] so are those the only two options I have I mean it\'s only really one option',
#  "[uni/] right but they're actually there are a lot more options on the pharmacy website that you can explore",
#  'I Please have the website address please',
#  'of course it so it\'s super easy it\'s just W. W. W. dot "Bartell Drugs" dot com and on the left hand side of the main page there are some links and one of them is listed as birth control [uni/]',
#  '[n_s/] you said birth control I mean [filler/] yes yes yes yes [n_s/]',
#  'I did [n_s/] so you just want to click any of that and it should answer any questions do you have anything else I can help you with',
#  '[uni/] you know m- so most of your information has been very helpful thank you',
#  "you're welcome i do appreciate you calling in and asking your questions If you have any further in the future please don't hesitate to call back",
#  'Also I think and I thank for your help so I could call you at anytime and ask questions about [uni/] right',
#  'yes definitely anytime you have any questions about birth control you can go ahead and ask [n_s/] alright you have a fantastic day bye',
#  '[n_s/] You too Goodbye',
#  '[n_s/] Hey there this is "Rite Aid" my name is "John" How can I help you today',
#  'hi there "John" I\'ve been taking a brand name medication that\'s been getting pretty pricey and I wanted to check if there was a cheaper generic I could use',
#  "[n_s/] alright I'd be more than happy to check to see if there's any generic options for you may i first have your name please",
#  '[n_s/] sure It is" Amber Brown',
#  'alright "Amber" and would you please confirm your home address for me so i make sure I have the right account pulled up',
#  'sure It\'s one seven eight five "North Pine',
#  "[n_s/] alright thank you for that I do have your account pulled up here and it looks like you currently have several different medications may i ask which one you're calling in today about looking for a generic version",
#  "Yes this is a lot that I'm interested in today",
#  '[n_s/] Alright [uni/] give me just a few moments as I check our inventory to see what we can do for you',
#  'alright [n_s/] thanks for waiting I have been able to find an alternative for you that may be a good option and that medication is called "Amlodipine" [filler/] however I do wanna make sure you\'re aware that it covered by your insurance',
#  'so what they\'d ask if we are you currently on \'Medicaid" [uni/]',
#  "[n_s/] Okay alright I'm on Medicare okay can you just give me a few more moments let me do a little further research on your current Insurance to see if that would cover",
#  'okay i can wait [n_s/]',
#  "well that's really too bad It's one that been around awhile to Is there any other option for getting the cough syrup",
#  "[n_s/] what another option sometimes is changing the amount of the dosage of the medication [filler/] so give me just a moment here I'll check to see if that's something we could do for you to save a call",
#  'alright thanks for waiting again for me [filler/] I had mailed figure this out to change your dose to behalf of your prescribed size the actually be saving substantially a lot of money',
#  "okay now I don't want to actually lower the amount of medicine I'm taking what I be covered to get a sufficient quantity to take two of the half dose pill instead of just one [n_s/]",
#  "absolutely that's exactly how you go about using this change and if it is something you want to proceed forward [filler/] I can go ahead and contact your doctor's office and requested that modification",
#  'that would be fabulous I wish they had suggested that to me [n_s/]',
#  "well [n_s/] that's what we're here for so I will go ahead and contact your doctor's office to make that request as soon as you're off of mine here today [n_s/] alright",
#  'okay I really appreciate it very much',
#  "your very welcome we actually get this request quite often So it shouldn't be a problem for me to reach out to the doctor's office to make that kind of change",
#  "[n_s/] so that's great when do you think it will be ready",
#  "so [n_s/] once we get the trees prescription over to them and they verify everything is good with the request down I'm going to make you receive a notification once the medication is ready so whether that's going to be a phone call or a text message whatever you normally receive from your office and that process with normal taken in working one to three hours depending how busy the [n_s/] doctor",
#  "[n_s/] okay that's not too bad well thank you so much for your help today",
#  "[n_s/] you're very welcome I'm glad I was able to help you here today and there's nothing else we could help us I hope you have a wonderful rest of your day alright",
#  '[n_s/] okay thanks again goodbye [n_s/]',
#  '[n_s/] hello there my name is "Joe" thank you for calling "C. B. A." how can we help you today',
#  "Hi Joe I've been taking extra Staton and I was wondering if you could tell me Is that cheaper Generic option available",
#  '[n_s/] we would be more than happy to check into that see what we could do for you may i have your name please [n_s/] may i have your first and last name please to complete your information',
#  '[filler/] [filler/] yes yes sure it\'s it\'s "Sally" "S.A.L.L.Y" "Jones" "J.O.N.E.S" [n_s/]',
#  'alright "Sally" and just to make sure I have the right account in front of me could you confirm your home address for me',
#  'sure it\'s on thirteen thirteen "Mockingbird Lane',
#  '[uni/] [filler/] I think that I do have your account pulled up and I see that you have several medications on file which one is specifically why you calling him today about [uni/]',
#  '[filler/] "LeBrons',
#  "[filler/] that's the thing with the mess around here so can you just a few moments here as I check our inventory to see if we have any alternatives available for you [n_s/]",
#  'alright thank you for waiting on the terminal that you might be worthwhile here and it\'s called "Tetracycline HCL" however it might not covered by insurance so i wanna ask you do you know are you currently on "medic Aid']

# %% [markdown]
# The data is already in lower case. We will proceed to some preprocessing steps to help represent the text appropriately.

# %% [markdown]
# ### Data Pre-Processing

# %% [markdown]
# #### Chunking

# %% [markdown]
# We will use a chunker to chunk up the texts into smaller sections.

# %%
# load tagger
tagger = SequenceTagger.load("flair/chunk-english")
# Out:
# 2023-06-21 18:42:41,919 SequenceTagger predicts: Dictionary with 47 tags: O, S-NP, B-NP, E-NP, I-NP, S-VP, B-VP, E-VP, I-VP, S-PP, B-PP, E-PP, I-PP, S-ADVP, B-ADVP, E-ADVP, I-ADVP, S-SBAR, B-SBAR, E-SBAR, I-SBAR, S-ADJP, B-ADJP, E-ADJP, I-ADJP, S-PRT, B-PRT, E-PRT, I-PRT, S-CONJP, B-CONJP, E-CONJP, I-CONJP, S-INTJ, B-INTJ, E-INTJ, I-INTJ, S-LST, B-LST, E-LST, I-LST, S-UCP, B-UCP, E-UCP, I-UCP, <START>, <STOP>

# %%
tagger
# Out:
# SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#       )
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=4096, out_features=4096, bias=True)
#   (rnn): LSTM(4096, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=47, bias=True)
#   (loss_function): ViterbiLoss()
#   (crf): CRF()
# )

# %% [markdown]
# A quick overview of how it works on our text corpus sentences.

# %%
# make example sentence
sentences = [Sentence(sent) for sent in data.text.to_list()[:10]]

# predict NER tags
tagger.predict(sentences)

# print predicted NER spans
for sentence in sentences:
  print()
  print('The following chunks are found in:', sentence.text)
  print()
  # iterate over entities and print
  for entity in sentence.get_spans('np'):
      print(entity)
# Out:
# The following chunks are found in: hi how are you thank you for calling chase bank how can i help you
#
# Span[1:2]: "how" → ADVP (0.9997)
# Span[3:4]: "you" → NP (0.9999)
# Span[4:5]: "thank" → VP (0.9998)
# Span[5:6]: "you" → NP (0.9999)
# Span[6:7]: "for" → PP (0.9999)
# Span[7:8]: "calling" → VP (1.0)
# Span[8:10]: "chase bank" → NP (0.8101)
# Span[10:11]: "how" → ADVP (0.9999)
# Span[12:13]: "i" → NP (0.9999)
# Span[13:14]: "help" → VP (0.9996)
# Span[14:15]: "you" → NP (0.9999)
#
# The following chunks are found in: that's really nice i can definitely help you with that can i have your full name
#
# Span[0:1]: "that" → NP (1.0)
# Span[1:2]: "'s" → VP (1.0)
# Span[2:4]: "really nice" → ADJP (0.8709)
# Span[4:5]: "i" → NP (0.9994)
# Span[5:8]: "can definitely help" → VP (0.998)
# Span[8:9]: "you" → NP (1.0)
# Span[9:10]: "with" → PP (1.0)
# Span[10:11]: "that" → NP (0.9846)
# Span[12:13]: "i" → NP (1.0)
# Span[13:14]: "have" → VP (1.0)
# Span[14:17]: "your full name" → NP (0.9976)
#
# The following chunks are found in: missus miss smith can i also have your national insurance number
#
# Span[0:3]: "missus miss smith" → NP (0.8621)
# Span[5:6]: "also" → ADVP (1.0)
# Span[6:7]: "have" → VP (0.9985)
# Span[7:11]: "your national insurance number" → NP (0.9832)
#
# The following chunks are found in: now how much are you looking to donate to your daughter
#
# Span[0:1]: "now" → ADVP (0.997)
# Span[1:3]: "how much" → NP (0.4685)
# Span[4:5]: "you" → NP (1.0)
# Span[5:6]: "looking" → VP (0.9994)
# Span[6:8]: "to donate" → VP (0.9248)
# Span[8:9]: "to" → PP (1.0)
# Span[9:11]: "your daughter" → NP (0.9998)
#
# The following chunks are found in: so that amount will be subject to taxes if you don't want to pay taxes which i'm assuming you wouldn't <filler> a tax-free gift has to be <filler> no higher than thirty thousand dollars
#
# Span[1:3]: "that amount" → NP (0.9755)
# Span[3:5]: "will be" → VP (0.9461)
# Span[5:6]: "subject" → ADJP (1.0)
# Span[6:7]: "to" → PP (1.0)
# Span[7:8]: "taxes" → NP (1.0)
# Span[8:9]: "if" → SBAR (1.0)
# Span[9:10]: "you" → NP (1.0)
# Span[10:15]: "don't want to pay" → VP (0.9968)
# Span[15:16]: "taxes" → NP (1.0)
# Span[16:17]: "which" → NP (1.0)
# Span[17:18]: "i" → NP (1.0)
# Span[18:20]: "'m assuming" → VP (0.9839)
# Span[20:21]: "you" → NP (1.0)
# Span[21:22]: "would" → VP (0.9559)
# Span[24:25]: "filler" → NP (0.9998)
# Span[26:29]: "a tax-free gift" → NP (0.9969)
# Span[29:32]: "has to be" → VP (0.8239)
# Span[33:34]: "filler" → NP (0.9944)
# Span[35:41]: "no higher than thirty thousand dollars" → NP (0.7099)
#
# The following chunks are found in: great so now <filler> do you know approximately when your daugh your daughter plans <filler> it was your daughter yeah plans to purchase her home the home
#
# Span[0:3]: "great so now" → ADVP (0.5571)
# Span[4:5]: "filler" → NP (0.9581)
# Span[7:8]: "you" → NP (1.0)
# Span[8:9]: "know" → VP (1.0)
# Span[9:10]: "approximately" → ADVP (0.9844)
# Span[10:11]: "when" → ADVP (0.8096)
# Span[11:13]: "your daugh" → NP (0.8864)
# Span[13:15]: "your daughter" → NP (0.9309)
# Span[15:16]: "plans" → VP (1.0)
# Span[17:18]: "filler" → NP (0.908)
# Span[19:20]: "it" → NP (1.0)
# Span[20:21]: "was" → VP (1.0)
# Span[21:23]: "your daughter" → NP (0.9969)
# Span[24:27]: "plans to purchase" → VP (0.8387)
# Span[27:29]: "her home" → NP (0.9274)
# Span[29:31]: "the home" → NP (0.9999)
#
# The following chunks are found in: now <filler> is there any anything that i could advise you about during this time
#
# Span[0:1]: "now" → ADVP (0.9226)
# Span[2:3]: "filler" → NP (0.9999)
# Span[4:5]: "is" → VP (0.9986)
# Span[5:6]: "there" → NP (0.9761)
# Span[6:8]: "any anything" → NP (0.9765)
# Span[8:9]: "that" → NP (1.0)
# Span[9:10]: "i" → NP (1.0)
# Span[10:12]: "could advise" → VP (0.9848)
# Span[12:13]: "you" → NP (1.0)
# Span[13:14]: "about" → PP (0.9987)
# Span[14:15]: "during" → PP (1.0)
# Span[15:17]: "this time" → NP (0.9999)
#
# The following chunks are found in: of course no i understand so <filler> fortunately because of covid and everything they are doing video calls we <filler> i can if you'd like i can schedule a video call instead
#
# Span[0:1]: "of" → PP (0.9999)
# Span[1:2]: "course" → NP (0.9978)
# Span[3:4]: "i" → NP (0.997)
# Span[4:5]: "understand" → VP (1.0)
# Span[5:6]: "so" → ADVP (0.7569)
# Span[7:8]: "filler" → NP (0.947)
# Span[9:10]: "fortunately" → ADVP (0.9997)
# Span[10:12]: "because of" → PP (0.9802)
# Span[12:13]: "covid" → NP (0.9284)
# Span[14:15]: "everything" → NP (0.9965)
# Span[15:16]: "they" → NP (1.0)
# Span[16:18]: "are doing" → VP (0.9718)
# Span[18:20]: "video calls" → NP (0.9906)
# Span[20:21]: "we" → NP (1.0)
# Span[22:23]: "filler" → NP (0.8647)
# Span[24:25]: "i" → NP (0.9986)
# Span[25:26]: "can" → VP (0.9945)
# Span[26:27]: "if" → SBAR (1.0)
# Span[27:28]: "you" → NP (1.0)
# Span[28:30]: "'d like" → VP (0.8575)
# Span[30:31]: "i" → NP (1.0)
# Span[31:33]: "can schedule" → VP (0.9887)
# Span[33:36]: "a video call" → NP (0.9647)
# Span[36:37]: "instead" → ADVP (0.9922)
#
# The following chunks are found in: me see if that works yeah thursday is definitely open how is two p m
#
# Span[0:1]: "me" → NP (1.0)
# Span[1:2]: "see" → VP (1.0)
# Span[2:3]: "if" → SBAR (1.0)
# Span[3:4]: "that" → NP (0.9998)
# Span[4:5]: "works" → VP (1.0)
# Span[5:6]: "yeah" → NP (0.8119)
# Span[6:7]: "thursday" → NP (0.7163)
# Span[7:8]: "is" → VP (1.0)
# Span[8:9]: "definitely" → ADVP (0.9995)
# Span[9:10]: "open" → ADJP (0.9999)
# Span[10:11]: "how" → ADVP (0.9994)
# Span[11:12]: "is" → VP (0.6133)
# Span[12:14]: "two p" → NP (0.9928)
#
# The following chunks are found in: me see <filler> yep they have ten a m open so i'm just gonna repeat the details to you <filler> you'll be having a video chat with the branch on thursday at ten a m
#
# Span[0:1]: "me" → NP (0.9999)
# Span[1:2]: "see" → VP (1.0)
# Span[3:4]: "filler" → NP (0.5754)
# Span[6:7]: "they" → NP (1.0)
# Span[7:8]: "have" → VP (0.9999)
# Span[8:11]: "ten a m" → NP (0.7521)
# Span[11:12]: "open" → ADJP (0.6632)
# Span[13:14]: "i" → NP (1.0)
# Span[14:18]: "'m just gonna repeat" → VP (0.9548)
# Span[18:20]: "the details" → NP (0.9998)
# Span[20:21]: "to" → PP (1.0)
# Span[21:22]: "you" → NP (0.9987)
# Span[23:24]: "filler" → NP (0.9879)
# Span[25:26]: "you" → NP (1.0)
# Span[26:29]: "'ll be having" → VP (0.9884)
# Span[29:32]: "a video chat" → NP (0.9957)
# Span[32:33]: "with" → PP (1.0)
# Span[33:35]: "the branch" → NP (0.9997)
# Span[35:36]: "on" → PP (1.0)
# Span[36:37]: "thursday" → NP (0.9999)
# Span[37:38]: "at" → PP (1.0)
# Span[38:39]: "ten" → NP (0.995)
# Span[39:41]: "a m" → NP (0.8675)

# %% [markdown]
# Nah, the chunk qualities aren't good.

# %% [markdown]
# #### Topic Modelling

# %% [markdown]
# We will use words instead of entire sentences.

# %%
# we don't want our topic model be affected by stop words
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
docs = list(set(
    [word for text in data.Transcription for word in str(text).split() if word not in stopwords]
))

# %%
len(docs)
# Out:
# 4167

# %%
topic_model = BERTopic(verbose=True, nr_topics='auto')
topics, probs = topic_model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/131 [00:00<?, ?it/s]
# 2023-06-21 19:32:49,528 - BERTopic - Transformed documents to Embeddings
# 2023-06-21 19:32:51,660 - BERTopic - Reduced dimensionality
# 2023-06-21 19:32:51,736 - BERTopic - Clustered reduced embeddings
# 2023-06-21 19:32:51,805 - BERTopic - Reduced number of topics from 102 to 28

# %%
topic_model.visualize_barchart(top_n_topics=26)

# %%
topic_model.visualize_documents(docs)

# %% [markdown]
# Let's try converting a text from our corpus to representative topics.

# %%
text = data.Transcription.to_list()[-100]
text
# Out:
# '[filler/] we have I have high cholesterol and [filler/] one of my family members has had diebetes'

# %%
# this is the view the topic model will be provided
topic_model_view = [word for word in text.split() if word not in stopwords]
topic_model_view
# Out:
# ['[filler/]',
#  'I',
#  'high',
#  'cholesterol',
#  '[filler/]',
#  'one',
#  'family',
#  'members',
#  'diebetes']

# %%
topic_view = [topic_model.find_topics(word, top_n=5) for word in topic_model_view]

# %%
text_topic_rep = [[topic_model.get_topic(topic_id) for topic_id in topics[0]] for topics in topic_view]

# %%
print('Text from corpus:', text)
print('Stopwords removed:', topic_model_view)
print('Topics Cluster for this text:')
print()
for word, topics in zip(topic_model_view, text_topic_rep):
    print(word, ':')
    for topic in topics:
        print('-', [topic_word[0] for topic_word in topic])
    print()
# Out:
# Text from corpus: [filler/] we have I have high cholesterol and [filler/] one of my family members has had diebetes
# Stopwords removed: ['[filler/]', 'I', 'high', 'cholesterol', '[filler/]', 'one', 'family', 'members', 'diebetes']
# Topics Cluster for this text:
#
# [filler/] :
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
# - ['preparation', 'solves', 'math', 'formulation', 'formulate', 'formulas', 'formula', 'factors', 'factor', 'equation']
# - ['hospital', 'pharmacy', 'medication', 'medic', 'advil', 'amoxicillin', 'med', 'lithium', 'drugs', 'drug']
#
# I :
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['id', 'ill', 'will', 'theyll', 'itll', 'well', 'youll', 'wed', 'theyd', 'thatd']
# - ['www', 'ws', 'wht', 'moly', 'isw', 'byw', '', '', '', '']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
#
# high :
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['boost', 'rising', 'reinforce', 'raise', 'increasing', 'increases', 'increased', 'increase', 'gaining', 'gain']
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['amount', 'measure', 'mil', 'total', 'tons', 'thousand', 'rate', 'quarter', 'quantity', 'percentage']
# - ['whats', 'something', 'nothing', 'anything', 'what', 'thingy', 'thingsthings', 'things', 'thing', 'stuff']
#
# cholesterol :
# - ['hospital', 'pharmacy', 'medication', 'medic', 'advil', 'amoxicillin', 'med', 'lithium', 'drugs', 'drug']
# - ['weightlifting', 'routine', 'physical', 'muscular', 'muscles', 'muscle', 'gym', 'exercising', 'exercises', 'exercised']
# - ['prilosec', 'pantoprazole', 'claritin', 'metoclopramide', 'cetirizine', 'esomeprazole', 'prolisec', 'pricy', 'pantoprazol', 'pantoprazo']
# - ['bartell', 'bartells', 'bartel', 'wwwbartelldot', 'karloff', 'claranite', 'bartels', 'bartelldrugs', 'barteldrugsdot', 'barteldrugs']
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
#
# [filler/] :
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
# - ['preparation', 'solves', 'math', 'formulation', 'formulate', 'formulas', 'formula', 'factors', 'factor', 'equation']
# - ['hospital', 'pharmacy', 'medication', 'medic', 'advil', 'amoxicillin', 'med', 'lithium', 'drugs', 'drug']
#
# one :
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['amount', 'measure', 'mil', 'total', 'tons', 'thousand', 'rate', 'quarter', 'quantity', 'percentage']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
# - ['colors', 'white', 'green', 'orange', 'grey', 'blue', 'golden', 'turquoise', 'shades', 'red']
#
# family :
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['halloween', 'christmas', 'witches', 'pumpkins', 'holidays', 'holiday', 'decorations', 'santa', '', '']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
# - ['drive', 'ride', 'bus', 'car', 'trailer', 'stables', 'riding', 'rider', 'rideit', 'porsche']
#
# members :
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['amount', 'measure', 'mil', 'total', 'tons', 'thousand', 'rate', 'quarter', 'quantity', 'percentage']
# - ['whole', 'together', 'separately', 'portion', 'mixup', 'mixing', 'mixes', 'mixed', 'mix', 'married']
# - ['drive', 'ride', 'bus', 'car', 'trailer', 'stables', 'riding', 'rider', 'rideit', 'porsche']
#
# diebetes :
# - ['riteaid', 'allegra', 'clarinet', 'aid', 'walgreens', 'george', 'smith', 'god', 'daniels', 'am']
# - ['jones', 'com', 'connecticut', 'gmail', 'and', 'west', 'nevada', 'my', 'made', 'candy']
# - ['hospital', 'pharmacy', 'medication', 'medic', 'advil', 'amoxicillin', 'med', 'lithium', 'drugs', 'drug']
# - ['halloween', 'christmas', 'witches', 'pumpkins', 'holidays', 'holiday', 'decorations', 'santa', '', '']
# - ['stds', 'ns', 'ds', 'stis', 'std', 'stameys', 'ststd', 'pollacks', 'jacks', 'hecks']
